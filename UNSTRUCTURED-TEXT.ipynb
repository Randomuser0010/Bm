# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, ne_chunk
import string
import collections
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('maxent_ne_chunker')
nltk.download('words')


text = """
The all-new BMW M340i went on sale in India in March this year and it's the latest addition to the 3 Series line-up. The performance-oriented BMW M340i sits right at the top in the 3 Series range and rivals the likes of the Mercedes-AMG A 35 4 Matic and the Audi S5. BMW is manufacturing the BMW M340i locally in India and the company will be selling it in limited numbers in our market. If you are planning to buy the new BMW M340i, here are few pros and cons you should have a look at.

Most Powerful 3 Series: It's the fastest and most powerful 3 Series money can buy. It features a 3.0-litre, six-cylinder engine under the hood that belts out 387 bhp and a solid 500 Nm of peak torque. The powertrain provides enough grunt to the M340i for it to do the 0-100 kmph sprint in just 4.4 seconds making it seriously quick for its segment.
All-Wheel-Drive: Yes! The eight-speed automatic transmission in the BMW M340i sends power to all the four wheels. And yes! It also gets paddle shifters.
The ride quality is stiff but complements the performance well. The M340i also sits lower by 10 mm over the standard 3

MSport Features: The BMW M340i also gets a new lift-related damper control and has the M Sport differential that is electronically controlled. The Adaptive M suspension with electronically controlled dampers offers a good mix of ride and handling.
The cabin of the BMW M340i could have given a sportier treatment.

Feature Loaded Cabin: The cabin of the new BMW M340i gets all the bells and whistles seen on the standard 3 Series sedan and then some. From the sunroof to the 12.3-inch instrument panel- and even the large 10.25-inch touchscreen with connectivity tech- all are standard.
Looks Sharp And Sporty: The new kidney grille with chrome bezels, sharp and sleek headlights, and the muscular bumper, all add to its sporty and aggressive demeanour. In India the car rides on 18-inch wheels that are standard while can be upgraded to 19-inch units which are optional.
Expensive Proposition: At an ex-showroom price of 62.90 lakh, the BMW M340i won't be easy on your pocket. In fact, ex-showroom price for the BMW 5 Series starts at Rs. 56.00 lakh.
Ground Clearance: Low ground clearance has always been a concern for drivers in India and we often fear about scraping the belly of our cars. Compared to the regular 3 Series, the M340i sits lower by about 10 mm.
The BMW M340i will be locally-assembled in India.

Cabin Looks Similar To 3 Series: On the inside, the BMW M340i doesn't feel too special and looks quite like the standard 3 Series, save for the those Alcantara upholstery. Attributes like red inserts and dual-red stitching along with flat bottom steering wheel added bolstering or side support in the seats would have added to its sporty character.

"""
text = text.strip()
text = text.lower()
tokens = word_tokenize(text)
tokens = [text for text in tokens if text not in stopwords.words('english')]
tokens = [text for text in tokens if text not in string.punctuation]

fdist = FreqDist(tokens)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

pos_tags = pos_tag(filtered_tokens)


named_entities = ne_chunk(pos_tags)

plt.figure(figsize=(12, 6))
fdist.plot(60, cumulative=False)  
plt.show()

print("Original Tokens:", tokens)
print("\nFrequency Distribution:", fdist)
print("\nFiltered Tokens (Without Stopwords):", filtered_tokens)
print("\nStemmed Tokens:", stemmed_tokens)
print("\nLemmatized Tokens:", lemmatized_tokens)
print("\nParts of Speech Tagging:", pos_tags)
print("\nNamed Entity Recognition:", named_entities)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Original Tokens: ['all-new', 'bmw', 'm340i', 'went', 'sale', 'india', 'march', 'year', "'s", 'latest', 'addition', '3', 'series', 'line-up', 'performance-oriented', 'bmw', 'm340i', 'sits', 'right', 'top', '3', 'series', 'range', 'rivals', 'likes', 'mercedes-amg', '35', '4', 'matic', 'audi', 's5', 'bmw', 'manufacturing', 'bmw', 'm340i', 'locally', 'india', 'company', 'selling', 'limited', 'numbers', 'market', 'planning', 'buy', 'new', 'bmw', 'm340i', 'pros', 'cons', 'look', 'powerful', '3', 'series', "'s", 'fastest', 'powerful', '3', 'series', 'money', 'buy', 'features', '3.0-litre', 'six-cylinder', 'engine', 'hood', 'belts', '387', 'bhp', 'solid', '500', 'nm', 'peak', 'torque', 'powertrain', 'provides', 'enough', 'grunt', 'm340i', '0-100', 'kmph', 'sprint', '4.4', 'seconds', 'making', 'seriously', 'quick', 'segment', 'all-wheel-drive', 'yes', 'eight-speed', 'automatic', 'transmission', 'bmw', 'm340i', 'sends', 'power', 'four', 'wheels', 'yes', 'also', 'gets', 'paddle', 'shifters', 'ride', 'quality', 'stiff', 'complements', 'performance', 'well', 'm340i', 'also', 'sits', 'lower', '10', 'mm', 'standard', '3', 'msport', 'features', 'bmw', 'm340i', 'also', 'gets', 'new', 'lift-related', 'damper', 'control', 'sport', 'differential', 'electronically', 'controlled', 'adaptive', 'suspension', 'electronically', 'controlled', 'dampers', 'offers', 'good', 'mix', 'ride', 'handling', 'cabin', 'bmw', 'm340i', 'could', 'given', 'sportier', 'treatment', 'feature', 'loaded', 'cabin', 'cabin', 'new', 'bmw', 'm340i', 'gets', 'bells', 'whistles', 'seen', 'standard', '3', 'series', 'sedan', 'sunroof', '12.3-inch', 'instrument', 'panel-', 'even', 'large', '10.25-inch', 'touchscreen', 'connectivity', 'tech-', 'standard', 'looks', 'sharp', 'sporty', 'new', 'kidney', 'grille', 'chrome', 'bezels', 'sharp', 'sleek', 'headlights', 'muscular', 'bumper', 'add', 'sporty', 'aggressive', 'demeanour', 'india', 'car', 'rides', '18-inch', 'wheels', 'standard', 'upgraded', '19-inch', 'units', 'optional', 'expensive', 'proposition', 'ex-showroom', 'price', '62.90', 'lakh', 'bmw', 'm340i', 'wo', "n't", 'easy', 'pocket', 'fact', 'ex-showroom', 'price', 'bmw', '5', 'series', 'starts', 'rs', '56.00', 'lakh', 'ground', 'clearance', 'low', 'ground', 'clearance', 'always', 'concern', 'drivers', 'india', 'often', 'fear', 'scraping', 'belly', 'cars', 'compared', 'regular', '3', 'series', 'm340i', 'sits', 'lower', '10', 'mm', 'bmw', 'm340i', 'locally-assembled', 'india', 'cabin', 'looks', 'similar', '3', 'series', 'inside', 'bmw', 'm340i', "n't", 'feel', 'special', 'looks', 'quite', 'like', 'standard', '3', 'series', 'save', 'alcantara', 'upholstery', 'attributes', 'like', 'red', 'inserts', 'dual-red', 'stitching', 'along', 'flat', 'bottom', 'steering', 'wheel', 'added', 'bolstering', 'side', 'support', 'seats', 'would', 'added', 'sporty', 'character']
#
# Frequency Distribution: <FreqDist with 204 samples and 290 outcomes>
#
# Filtered Tokens (Without Stopwords): ['all-new', 'bmw', 'm340i', 'went', 'sale', 'india', 'march', 'year', "'s", 'latest', 'addition', '3', 'series', 'line-up', 'performance-oriented', 'bmw', 'm340i', 'sits', 'right', 'top', '3', 'series', 'range', 'rivals', 'likes', 'mercedes-amg', '35', '4', 'matic', 'audi', 's5', 'bmw', 'manufacturing', 'bmw', 'm340i', 'locally', 'india', 'company', 'selling', 'limited', 'numbers', 'market', 'planning', 'buy', 'new', 'bmw', 'm340i', 'pros', 'cons', 'look', 'powerful', '3', 'series', "'s", 'fastest', 'powerful', '3', 'series', 'money', 'buy', 'features', '3.0-litre', 'six-cylinder', 'engine', 'hood', 'belts', '387', 'bhp', 'solid', '500', 'nm', 'peak', 'torque', 'powertrain', 'provides', 'enough', 'grunt', 'm340i', '0-100', 'kmph', 'sprint', '4.4', 'seconds', 'making', 'seriously', 'quick', 'segment', 'all-wheel-drive', 'yes', 'eight-speed', 'automatic', 'transmission', 'bmw', 'm340i', 'sends', 'power', 'four', 'wheels', 'yes', 'also', 'gets', 'paddle', 'shifters', 'ride', 'quality', 'stiff', 'complements', 'performance', 'well', 'm340i', 'also', 'sits', 'lower', '10', 'mm', 'standard', '3', 'msport', 'features', 'bmw', 'm340i', 'also', 'gets', 'new', 'lift-related', 'damper', 'control', 'sport', 'differential', 'electronically', 'controlled', 'adaptive', 'suspension', 'electronically', 'controlled', 'dampers', 'offers', 'good', 'mix', 'ride', 'handling', 'cabin', 'bmw', 'm340i', 'could', 'given', 'sportier', 'treatment', 'feature', 'loaded', 'cabin', 'cabin', 'new', 'bmw', 'm340i', 'gets', 'bells', 'whistles', 'seen', 'standard', '3', 'series', 'sedan', 'sunroof', '12.3-inch', 'instrument', 'panel-', 'even', 'large', '10.25-inch', 'touchscreen', 'connectivity', 'tech-', 'standard', 'looks', 'sharp', 'sporty', 'new', 'kidney', 'grille', 'chrome', 'bezels', 'sharp', 'sleek', 'headlights', 'muscular', 'bumper', 'add', 'sporty', 'aggressive', 'demeanour', 'india', 'car', 'rides', '18-inch', 'wheels', 'standard', 'upgraded', '19-inch', 'units', 'optional', 'expensive', 'proposition', 'ex-showroom', 'price', '62.90', 'lakh', 'bmw', 'm340i', 'wo', "n't", 'easy', 'pocket', 'fact', 'ex-showroom', 'price', 'bmw', '5', 'series', 'starts', 'rs', '56.00', 'lakh', 'ground', 'clearance', 'low', 'ground', 'clearance', 'always', 'concern', 'drivers', 'india', 'often', 'fear', 'scraping', 'belly', 'cars', 'compared', 'regular', '3', 'series', 'm340i', 'sits', 'lower', '10', 'mm', 'bmw', 'm340i', 'locally-assembled', 'india', 'cabin', 'looks', 'similar', '3', 'series', 'inside', 'bmw', 'm340i', "n't", 'feel', 'special', 'looks', 'quite', 'like', 'standard', '3', 'series', 'save', 'alcantara', 'upholstery', 'attributes', 'like', 'red', 'inserts', 'dual-red', 'stitching', 'along', 'flat', 'bottom', 'steering', 'wheel', 'added', 'bolstering', 'side', 'support', 'seats', 'would', 'added', 'sporty', 'character']
#
# Stemmed Tokens: ['all-new', 'bmw', 'm340i', 'went', 'sale', 'india', 'march', 'year', "'s", 'latest', 'addit', '3', 'seri', 'line-up', 'performance-ori', 'bmw', 'm340i', 'sit', 'right', 'top', '3', 'seri', 'rang', 'rival', 'like', 'mercedes-amg', '35', '4', 'matic', 'audi', 's5', 'bmw', 'manufactur', 'bmw', 'm340i', 'local', 'india', 'compani', 'sell', 'limit', 'number', 'market', 'plan', 'buy', 'new', 'bmw', 'm340i', 'pro', 'con', 'look', 'power', '3', 'seri', "'s", 'fastest', 'power', '3', 'seri', 'money', 'buy', 'featur', '3.0-litr', 'six-cylind', 'engin', 'hood', 'belt', '387', 'bhp', 'solid', '500', 'nm', 'peak', 'torqu', 'powertrain', 'provid', 'enough', 'grunt', 'm340i', '0-100', 'kmph', 'sprint', '4.4', 'second', 'make', 'serious', 'quick', 'segment', 'all-wheel-dr', 'ye', 'eight-spe', 'automat', 'transmiss', 'bmw', 'm340i', 'send', 'power', 'four', 'wheel', 'ye', 'also', 'get', 'paddl', 'shifter', 'ride', 'qualiti', 'stiff', 'complement', 'perform', 'well', 'm340i', 'also', 'sit', 'lower', '10', 'mm', 'standard', '3', 'msport', 'featur', 'bmw', 'm340i', 'also', 'get', 'new', 'lift-rel', 'damper', 'control', 'sport', 'differenti', 'electron', 'control', 'adapt', 'suspens', 'electron', 'control', 'damper', 'offer', 'good', 'mix', 'ride', 'handl', 'cabin', 'bmw', 'm340i', 'could', 'given', 'sportier', 'treatment', 'featur', 'load', 'cabin', 'cabin', 'new', 'bmw', 'm340i', 'get', 'bell', 'whistl', 'seen', 'standard', '3', 'seri', 'sedan', 'sunroof', '12.3-inch', 'instrument', 'panel-', 'even', 'larg', '10.25-inch', 'touchscreen', 'connect', 'tech-', 'standard', 'look', 'sharp', 'sporti', 'new', 'kidney', 'grill', 'chrome', 'bezel', 'sharp', 'sleek', 'headlight', 'muscular', 'bumper', 'add', 'sporti', 'aggress', 'demeanour', 'india', 'car', 'ride', '18-inch', 'wheel', 'standard', 'upgrad', '19-inch', 'unit', 'option', 'expens', 'proposit', 'ex-showroom', 'price', '62.90', 'lakh', 'bmw', 'm340i', 'wo', "n't", 'easi', 'pocket', 'fact', 'ex-showroom', 'price', 'bmw', '5', 'seri', 'start', 'rs', '56.00', 'lakh', 'ground', 'clearanc', 'low', 'ground', 'clearanc', 'alway', 'concern', 'driver', 'india', 'often', 'fear', 'scrape', 'belli', 'car', 'compar', 'regular', '3', 'seri', 'm340i', 'sit', 'lower', '10', 'mm', 'bmw', 'm340i', 'locally-assembl', 'india', 'cabin', 'look', 'similar', '3', 'seri', 'insid', 'bmw', 'm340i', "n't", 'feel', 'special', 'look', 'quit', 'like', 'standard', '3', 'seri', 'save', 'alcantara', 'upholsteri', 'attribut', 'like', 'red', 'insert', 'dual-r', 'stitch', 'along', 'flat', 'bottom', 'steer', 'wheel', 'ad', 'bolster', 'side', 'support', 'seat', 'would', 'ad', 'sporti', 'charact']
#
# Lemmatized Tokens: ['all-new', 'bmw', 'm340i', 'went', 'sale', 'india', 'march', 'year', "'s", 'latest', 'addition', '3', 'series', 'line-up', 'performance-oriented', 'bmw', 'm340i', 'sits', 'right', 'top', '3', 'series', 'range', 'rival', 'like', 'mercedes-amg', '35', '4', 'matic', 'audi', 's5', 'bmw', 'manufacturing', 'bmw', 'm340i', 'locally', 'india', 'company', 'selling', 'limited', 'number', 'market', 'planning', 'buy', 'new', 'bmw', 'm340i', 'pro', 'con', 'look', 'powerful', '3', 'series', "'s", 'fastest', 'powerful', '3', 'series', 'money', 'buy', 'feature', '3.0-litre', 'six-cylinder', 'engine', 'hood', 'belt', '387', 'bhp', 'solid', '500', 'nm', 'peak', 'torque', 'powertrain', 'provides', 'enough', 'grunt', 'm340i', '0-100', 'kmph', 'sprint', '4.4', 'second', 'making', 'seriously', 'quick', 'segment', 'all-wheel-drive', 'yes', 'eight-speed', 'automatic', 'transmission', 'bmw', 'm340i', 'sends', 'power', 'four', 'wheel', 'yes', 'also', 'get', 'paddle', 'shifter', 'ride', 'quality', 'stiff', 'complement', 'performance', 'well', 'm340i', 'also', 'sits', 'lower', '10', 'mm', 'standard', '3', 'msport', 'feature', 'bmw', 'm340i', 'also', 'get', 'new', 'lift-related', 'damper', 'control', 'sport', 'differential', 'electronically', 'controlled', 'adaptive', 'suspension', 'electronically', 'controlled', 'damper', 'offer', 'good', 'mix', 'ride', 'handling', 'cabin', 'bmw', 'm340i', 'could', 'given', 'sportier', 'treatment', 'feature', 'loaded', 'cabin', 'cabin', 'new', 'bmw', 'm340i', 'get', 'bell', 'whistle', 'seen', 'standard', '3', 'series', 'sedan', 'sunroof', '12.3-inch', 'instrument', 'panel-', 'even', 'large', '10.25-inch', 'touchscreen', 'connectivity', 'tech-', 'standard', 'look', 'sharp', 'sporty', 'new', 'kidney', 'grille', 'chrome', 'bezel', 'sharp', 'sleek', 'headlight', 'muscular', 'bumper', 'add', 'sporty', 'aggressive', 'demeanour', 'india', 'car', 'ride', '18-inch', 'wheel', 'standard', 'upgraded', '19-inch', 'unit', 'optional', 'expensive', 'proposition', 'ex-showroom', 'price', '62.90', 'lakh', 'bmw', 'm340i', 'wo', "n't", 'easy', 'pocket', 'fact', 'ex-showroom', 'price', 'bmw', '5', 'series', 'start', 'r', '56.00', 'lakh', 'ground', 'clearance', 'low', 'ground', 'clearance', 'always', 'concern', 'driver', 'india', 'often', 'fear', 'scraping', 'belly', 'car', 'compared', 'regular', '3', 'series', 'm340i', 'sits', 'lower', '10', 'mm', 'bmw', 'm340i', 'locally-assembled', 'india', 'cabin', 'look', 'similar', '3', 'series', 'inside', 'bmw', 'm340i', "n't", 'feel', 'special', 'look', 'quite', 'like', 'standard', '3', 'series', 'save', 'alcantara', 'upholstery', 'attribute', 'like', 'red', 'insert', 'dual-red', 'stitching', 'along', 'flat', 'bottom', 'steering', 'wheel', 'added', 'bolstering', 'side', 'support', 'seat', 'would', 'added', 'sporty', 'character']
#
# Parts of Speech Tagging: [('all-new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('went', 'VBD'), ('sale', 'NN'), ('india', 'NN'), ('march', 'VBP'), ('year', 'NN'), ("'s", 'POS'), ('latest', 'JJS'), ('addition', 'NN'), ('3', 'CD'), ('series', 'NN'), ('line-up', 'JJ'), ('performance-oriented', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('sits', 'NNS'), ('right', 'RB'), ('top', 'VBP'), ('3', 'CD'), ('series', 'NN'), ('range', 'NN'), ('rivals', 'NNS'), ('likes', 'VBZ'), ('mercedes-amg', 'JJ'), ('35', 'CD'), ('4', 'CD'), ('matic', 'JJ'), ('audi', 'NN'), ('s5', 'NN'), ('bmw', 'NN'), ('manufacturing', 'VBG'), ('bmw', 'NN'), ('m340i', 'NN'), ('locally', 'RB'), ('india', 'JJ'), ('company', 'NN'), ('selling', 'NN'), ('limited', 'JJ'), ('numbers', 'NNS'), ('market', 'NN'), ('planning', 'VBG'), ('buy', 'VB'), ('new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('pros', 'NNS'), ('cons', 'NNS'), ('look', 'VBP'), ('powerful', 'JJ'), ('3', 'CD'), ('series', 'NN'), ("'s", 'POS'), ('fastest', 'JJS'), ('powerful', 'JJ'), ('3', 'CD'), ('series', 'NN'), ('money', 'NN'), ('buy', 'VB'), ('features', 'NNS'), ('3.0-litre', 'JJ'), ('six-cylinder', 'JJ'), ('engine', 'NN'), ('hood', 'NN'), ('belts', 'NNS'), ('387', 'CD'), ('bhp', 'NN'), ('solid', 'JJ'), ('500', 'CD'), ('nm', 'JJ'), ('peak', 'NN'), ('torque', 'NN'), ('powertrain', 'NN'), ('provides', 'VBZ'), ('enough', 'JJ'), ('grunt', 'NN'), ('m340i', 'VBD'), ('0-100', 'JJ'), ('kmph', 'NN'), ('sprint', 'NN'), ('4.4', 'CD'), ('seconds', 'NNS'), ('making', 'VBG'), ('seriously', 'RB'), ('quick', 'JJ'), ('segment', 'NN'), ('all-wheel-drive', 'JJ'), ('yes', 'NNS'), ('eight-speed', 'JJ'), ('automatic', 'JJ'), ('transmission', 'NN'), ('bmw', 'NN'), ('m340i', 'NN'), ('sends', 'VBZ'), ('power', 'NN'), ('four', 'CD'), ('wheels', 'NNS'), ('yes', 'RB'), ('also', 'RB'), ('gets', 'VBZ'), ('paddle', 'JJ'), ('shifters', 'NNS'), ('ride', 'VBP'), ('quality', 'NN'), ('stiff', 'JJ'), ('complements', 'NNS'), ('performance', 'NN'), ('well', 'RB'), ('m340i', 'RB'), ('also', 'RB'), ('sits', 'VBZ'), ('lower', 'JJR'), ('10', 'CD'), ('mm', 'JJ'), ('standard', 'NN'), ('3', 'CD'), ('msport', 'NN'), ('features', 'NNS'), ('bmw', 'VBP'), ('m340i', 'NN'), ('also', 'RB'), ('gets', 'VBZ'), ('new', 'JJ'), ('lift-related', 'JJ'), ('damper', 'NN'), ('control', 'NN'), ('sport', 'NN'), ('differential', 'NN'), ('electronically', 'RB'), ('controlled', 'VBD'), ('adaptive', 'JJ'), ('suspension', 'NN'), ('electronically', 'RB'), ('controlled', 'VBD'), ('dampers', 'NNS'), ('offers', 'NNS'), ('good', 'JJ'), ('mix', 'NN'), ('ride', 'NN'), ('handling', 'VBG'), ('cabin', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('could', 'MD'), ('given', 'VBN'), ('sportier', 'VB'), ('treatment', 'NN'), ('feature', 'NN'), ('loaded', 'VBD'), ('cabin', 'NNS'), ('cabin', 'VBP'), ('new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('gets', 'VBZ'), ('bells', 'NNS'), ('whistles', 'NNS'), ('seen', 'VBN'), ('standard', 'JJ'), ('3', 'CD'), ('series', 'NN'), ('sedan', 'NN'), ('sunroof', 'JJ'), ('12.3-inch', 'JJ'), ('instrument', 'NN'), ('panel-', 'NN'), ('even', 'RB'), ('large', 'JJ'), ('10.25-inch', 'JJ'), ('touchscreen', 'JJ'), ('connectivity', 'NN'), ('tech-', 'JJ'), ('standard', 'NN'), ('looks', 'VBZ'), ('sharp', 'JJ'), ('sporty', 'JJ'), ('new', 'JJ'), ('kidney', 'NN'), ('grille', 'NN'), ('chrome', 'NN'), ('bezels', 'NNS'), ('sharp', 'JJ'), ('sleek', 'JJ'), ('headlights', 'NNS'), ('muscular', 'JJ'), ('bumper', 'IN'), ('add', 'JJ'), ('sporty', 'JJ'), ('aggressive', 'JJ'), ('demeanour', 'NN'), ('india', 'NN'), ('car', 'NN'), ('rides', 'VBZ'), ('18-inch', 'JJ'), ('wheels', 'NNS'), ('standard', 'NN'), ('upgraded', 'VBD'), ('19-inch', 'JJ'), ('units', 'NNS'), ('optional', 'JJ'), ('expensive', 'JJ'), ('proposition', 'NN'), ('ex-showroom', 'JJ'), ('price', 'NN'), ('62.90', 'CD'), ('lakh', 'NN'), ('bmw', 'NN'), ('m340i', 'NN'), ('wo', 'MD'), ("n't", 'RB'), ('easy', 'VB'), ('pocket', 'JJ'), ('fact', 'NN'), ('ex-showroom', 'JJ'), ('price', 'NN'), ('bmw', 'NN'), ('5', 'CD'), ('series', 'NN'), ('starts', 'V ...
#
# Named Entity Recognition: (S
#   all-new/JJ
#   bmw/NN
#   m340i/NN
#   went/VBD
#   sale/NN
#   india/NN
#   march/VBP
#   year/NN
#   's/POS
#   latest/JJS
#   addition/NN
#   3/CD
#   series/NN
#   line-up/JJ
#   performance-oriented/JJ
#   bmw/NN
#   m340i/NN
#   sits/NNS
#   right/RB
#   top/VBP
#   3/CD
#   series/NN
#   range/NN
#   rivals/NNS
#   likes/VBZ
#   mercedes-amg/JJ
#   35/CD
#   4/CD
#   matic/JJ
#   audi/NN
#   s5/NN
#   bmw/NN
#   manufacturing/VBG
#   bmw/NN
#   m340i/NN
#   locally/RB
#   india/JJ
#   company/NN
#   selling/NN
#   limited/JJ
#   numbers/NNS
#   market/NN
#   planning/VBG
#   buy/VB
#   new/JJ
#   bmw/NN
#   m340i/NN
#   pros/NNS
#   cons/NNS
#   look/VBP
#   powerful/JJ
#   3/CD
#   series/NN
#   's/POS
#   fastest/JJS
#   powerful/JJ
#   3/CD
#   series/NN
#   money/NN
#   buy/VB
#   features/NNS
#   3.0-litre/JJ
#   six-cylinder/JJ
#   engine/NN
#   hood/NN
#   belts/NNS
#   387/CD
#   bhp/NN
#   solid/JJ
#   500/CD
#   nm/JJ
#   peak/NN
#   torque/NN
#   powertrain/NN
#   provides/VBZ
#   enough/JJ
#   grunt/NN
#   m340i/VBD
#   0-100/JJ
#   kmph/NN
#   sprint/NN
#   4.4/CD
#   seconds/NNS
#   making/VBG
#   seriously/RB
#   quick/JJ
#   segment/NN
#   all-wheel-drive/JJ
#   yes/NNS
#   eight-speed/JJ
#   automatic/JJ
#   transmission/NN
#   bmw/NN
#   m340i/NN
#   sends/VBZ
#   power/NN
#   four/CD
#   wheels/NNS
#   yes/RB
#   also/RB
#   gets/VBZ
#   paddle/JJ
#   shifters/NNS
#   ride/VBP
#   quality/NN
#   stiff/JJ
#   complements/NNS
#   performance/NN
#   well/RB
#   m340i/RB
#   also/RB
#   sits/VBZ
#   lower/JJR
#   10/CD
#   mm/JJ
#   standard/NN
#   3/CD
#   msport/NN
#   features/NNS
#   bmw/VBP
#   m340i/NN
#   also/RB
#   gets/VBZ
#   new/JJ
#   lift-related/JJ
#   damper/NN
#   control/NN
#   sport/NN
#   differential/NN
#   electronically/RB
#   controlled/VBD
#   adaptive/JJ
#   suspension/NN
#   electronically/RB
#   controlled/VBD
#   dampers/NNS
#   offers/NNS
#   good/JJ
#   mix/NN
#   ride/NN
#   handling/VBG
#   cabin/JJ
#   bmw/NN
#   m340i/NN
#   could/MD
#   given/VBN
#   sportier/VB
#   treatment/NN
#   feature/NN
#   loaded/VBD
#   cabin/NNS
#   cabin/VBP
#   new/JJ
#   bmw/NN
#   m340i/NN
#   gets/VBZ
#   bells/NNS
#   whistles/NNS
#   seen/VBN
#   standard/JJ
#   3/CD
#   series/NN
#   sedan/NN
#   sunroof/JJ
#   12.3-inch/JJ
#   instrument/NN
#   panel-/NN
#   even/RB
#   large/JJ
#   10.25-inch/JJ
#   touchscreen/JJ
#   connectivity/NN
#   tech-/JJ
#   standard/NN
#   looks/VBZ
#   sharp/JJ
#   sporty/JJ
#   new/JJ
#   kidney/NN
#   grille/NN
#   chrome/NN
#   bezels/NNS
#   sharp/JJ
#   sleek/JJ
#   headlights/NNS
#   muscular/JJ
#   bumper/IN
#   add/JJ
#   sporty/JJ
#   aggressive/JJ
#   demeanour/NN
#   india/NN
#   car/NN
#   rides/VBZ
#   18-inch/JJ
#   wheels/NNS
#   standard/NN
#   upgraded/VBD
#   19-inch/JJ
#   units/NNS
#   optional/JJ
#   expensive/JJ
#   proposition/NN
#   ex-showroom/JJ
#   price/NN
#   62.90/CD
#   lakh/NN
#   bmw/NN
#   m340i/NN
#   wo/MD
#   n't/RB
#   easy/VB
#   pocket/JJ
#   fact/NN
#   ex-showroom/JJ
#   price/NN
#   bmw/NN
#   5/CD
#   series/NN
#   starts/VBZ
#   rs/JJ
#   56.00/CD
#   lakh/NN
#   ground/NN
#   clearance/NN
#   low/JJ
#   ground/NN
#   clearance/NN
#   always/RB
#   concern/NN
#   drivers/NNS
#   india/VBP
#   often/RB
#   fear/JJ
#   scraping/VBG
#   belly/RB
#   cars/NNS
#   compared/VBN
#   regular/JJ
#   3/CD
#   series/NN
#   m340i/NN
#   sits/VBZ
#   lower/JJR
#   10/CD
#   mm/NNS
#   bmw/JJ
#   m340i/JJ
#   locally-assembled/JJ
#   india/NN
#   cabin/NN
#   looks/VBZ
#   similar/JJ
#   3/CD
#   series/NN
#   inside/IN
#   bmw/JJ
#   m340i/VBP
#   n't/RB
#   feel/VB
#   special/JJ
#   looks/NNS
#   quite/RB
#   like/JJ
#   standard/NN
#   3/CD
#   series/NN
#   save/VBP
#   alcantara/VBN
#   upholstery/JJ
#   attributes/NNS
#   like/IN
#   red/JJ
#   inserts/NNS
#   dual-red/JJ
#   stitching/VBG
#   along/RB
#   flat/JJ
#   bottom/NN
#   steering/VBG
#   wheel/NN
#   added/VBD
#   bolstering/VBG
#   side/JJ
#   support/NN
#   seats/NNS
#   would/MD
#   added/VBD
#   sporty/NN
#   character/NN)

# %%
named_entities
# Out:
# Tree('S', [('all-new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('went', 'VBD'), ('sale', 'NN'), ('india', 'NN'), ('march', 'VBP'), ('year', 'NN'), ("'s", 'POS'), ('latest', 'JJS'), ('addition', 'NN'), ('3', 'CD'), ('series', 'NN'), ('line-up', 'JJ'), ('performance-oriented', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('sits', 'NNS'), ('right', 'RB'), ('top', 'VBP'), ('3', 'CD'), ('series', 'NN'), ('range', 'NN'), ('rivals', 'NNS'), ('likes', 'VBZ'), ('mercedes-amg', 'JJ'), ('35', 'CD'), ('4', 'CD'), ('matic', 'JJ'), ('audi', 'NN'), ('s5', 'NN'), ('bmw', 'NN'), ('manufacturing', 'VBG'), ('bmw', 'NN'), ('m340i', 'NN'), ('locally', 'RB'), ('india', 'JJ'), ('company', 'NN'), ('selling', 'NN'), ('limited', 'JJ'), ('numbers', 'NNS'), ('market', 'NN'), ('planning', 'VBG'), ('buy', 'VB'), ('new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('pros', 'NNS'), ('cons', 'NNS'), ('look', 'VBP'), ('powerful', 'JJ'), ('3', 'CD'), ('series', 'NN'), ("'s", 'POS'), ('fastest', 'JJS'), ('powerful', 'JJ'), ('3', 'CD'), ('series', 'NN'), ('money', 'NN'), ('buy', 'VB'), ('features', 'NNS'), ('3.0-litre', 'JJ'), ('six-cylinder', 'JJ'), ('engine', 'NN'), ('hood', 'NN'), ('belts', 'NNS'), ('387', 'CD'), ('bhp', 'NN'), ('solid', 'JJ'), ('500', 'CD'), ('nm', 'JJ'), ('peak', 'NN'), ('torque', 'NN'), ('powertrain', 'NN'), ('provides', 'VBZ'), ('enough', 'JJ'), ('grunt', 'NN'), ('m340i', 'VBD'), ('0-100', 'JJ'), ('kmph', 'NN'), ('sprint', 'NN'), ('4.4', 'CD'), ('seconds', 'NNS'), ('making', 'VBG'), ('seriously', 'RB'), ('quick', 'JJ'), ('segment', 'NN'), ('all-wheel-drive', 'JJ'), ('yes', 'NNS'), ('eight-speed', 'JJ'), ('automatic', 'JJ'), ('transmission', 'NN'), ('bmw', 'NN'), ('m340i', 'NN'), ('sends', 'VBZ'), ('power', 'NN'), ('four', 'CD'), ('wheels', 'NNS'), ('yes', 'RB'), ('also', 'RB'), ('gets', 'VBZ'), ('paddle', 'JJ'), ('shifters', 'NNS'), ('ride', 'VBP'), ('quality', 'NN'), ('stiff', 'JJ'), ('complements', 'NNS'), ('performance', 'NN'), ('well', 'RB'), ('m340i', 'RB'), ('also', 'RB'), ('sits', 'VBZ'), ('lower', 'JJR'), ('10', 'CD'), ('mm', 'JJ'), ('standard', 'NN'), ('3', 'CD'), ('msport', 'NN'), ('features', 'NNS'), ('bmw', 'VBP'), ('m340i', 'NN'), ('also', 'RB'), ('gets', 'VBZ'), ('new', 'JJ'), ('lift-related', 'JJ'), ('damper', 'NN'), ('control', 'NN'), ('sport', 'NN'), ('differential', 'NN'), ('electronically', 'RB'), ('controlled', 'VBD'), ('adaptive', 'JJ'), ('suspension', 'NN'), ('electronically', 'RB'), ('controlled', 'VBD'), ('dampers', 'NNS'), ('offers', 'NNS'), ('good', 'JJ'), ('mix', 'NN'), ('ride', 'NN'), ('handling', 'VBG'), ('cabin', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('could', 'MD'), ('given', 'VBN'), ('sportier', 'VB'), ('treatment', 'NN'), ('feature', 'NN'), ('loaded', 'VBD'), ('cabin', 'NNS'), ('cabin', 'VBP'), ('new', 'JJ'), ('bmw', 'NN'), ('m340i', 'NN'), ('gets', 'VBZ'), ('bells', 'NNS'), ('whistles', 'NNS'), ('seen', 'VBN'), ('standard', 'JJ'), ('3', 'CD'), ('series', 'NN'), ('sedan', 'NN'), ('sunroof', 'JJ'), ('12.3-inch', 'JJ'), ('instrument', 'NN'), ('panel-', 'NN'), ('even', 'RB'), ('large', 'JJ'), ('10.25-inch', 'JJ'), ('touchscreen', 'JJ'), ('connectivity', 'NN'), ('tech-', 'JJ'), ('standard', 'NN'), ('looks', 'VBZ'), ('sharp', 'JJ'), ('sporty', 'JJ'), ('new', 'JJ'), ('kidney', 'NN'), ('grille', 'NN'), ('chrome', 'NN'), ('bezels', 'NNS'), ('sharp', 'JJ'), ('sleek', 'JJ'), ('headlights', 'NNS'), ('muscular', 'JJ'), ('bumper', 'IN'), ('add', 'JJ'), ('sporty', 'JJ'), ('aggressive', 'JJ'), ('demeanour', 'NN'), ('india', 'NN'), ('car', 'NN'), ('rides', 'VBZ'), ('18-inch', 'JJ'), ('wheels', 'NNS'), ('standard', 'NN'), ('upgraded', 'VBD'), ('19-inch', 'JJ'), ('units', 'NNS'), ('optional', 'JJ'), ('expensive', 'JJ'), ('proposition', 'NN'), ('ex-showroom', 'JJ'), ('price', 'NN'), ('62.90', 'CD'), ('lakh', 'NN'), ('bmw', 'NN'), ('m340i', 'NN'), ('wo', 'MD'), ("n't", 'RB'), ('easy', 'VB'), ('pocket', 'JJ'), ('fact', 'NN'), ('ex-showroom', 'JJ'), ('price', 'NN'), ('bmw', 'NN'), ('5', 'CD'), ('series', 'NN'), ('starts', 'VBZ'), ('rs', 'J ...

# %%
len(text)
# Out:
# 2775
